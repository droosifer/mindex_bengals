# %%
from mindex_bengals import get_bengals_data, load_data_to_database, view_bengals_data_in_db
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 from mindex_bengals import get_bengals_data, load_data_to_database, view_bengals_data_in_db
#
# ImportError: cannot import name 'view_bengals_data_in_db' from 'mindex_bengals' (/home/drewringo/Projects/mindex_bengals/mindex_bengals.py)

# %%
begnals_data = get_bengals_data()

# %%
begnals_data
# Out:
#      Week Opponent Location  ... TD Boyd  TD Chase  TD Higgins
# 0    PRE1       TB     Away  ...     0.0       0.0         0.0
# 1    PRE2      WSH     Away  ...     0.0       0.0         0.0
# 2    PRE3      MIA     Home  ...     0.0       0.0         0.0
# 3    REG1      MIN     Home  ...     0.0       1.0         1.0
# 4    REG2      CHI     Away  ...     0.0       1.0         1.0
# 5    REG3      PIT     Away  ...     1.0       2.0         0.0
# 6    REG4      JAX     Home  ...     0.0       0.0         0.0
# 7    REG5       GB     Home  ...     0.0       1.0         0.0
# 8    REG6      DET     Away  ...     0.0       0.0         0.0
# 9    REG7      BAL     Away  ...     0.0       1.0         0.0
# 10   REG8      NYJ     Away  ...     1.0       1.0         0.0
# 11   REG9      CLE     Home  ...     0.0       0.0         0.0
# 13  REG11       LV     Away  ...     0.0       1.0         0.0
# 14  REG12      PIT     Home  ...     0.0       0.0         1.0
# 15  REG13      LAC     Home  ...     0.0       0.0         1.0
# 16  REG14       SF     Home  ...     0.0       2.0         0.0
# 17  REG15      DEN     Away  ...     1.0       0.0         0.0
# 18  REG16      BAL     Home  ...     1.0       0.0         2.0
# 19  REG17       KC     Home  ...     1.0       3.0         0.0
# 20  REG18      CLE     Away  ...     0.0       0.0         0.0
# 21  POST1       LV     Home  ...     1.0       0.0         0.0
# 22  POST2      TEN     Away  ...     0.0       0.0         0.0
# 23  POST3       KC     Away  ...     0.0       1.0         0.0
# 24  POST4      LAR  Neutral  ...     0.0       0.0         2.0
#
# [24 rows x 10 columns]

# %%
load_data_to_database = load_data_to_database(dataframe=begnals_data, table_name='drew_ringo')

# %%
view_bengals_data_in_db(table_name='drew_ringo')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 view_bengals_data_in_db(table_name='drew_ringo')
#
# NameError: name 'view_bengals_data_in_db' is not defined
